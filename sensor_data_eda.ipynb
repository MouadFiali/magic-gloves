# %%
import pandas as pd

# %%
# read sensor data
df = pd.read_csv('sensor_data.csv')

# %%
# number of rows and columns
print(df.shape)
# Out:
# (600, 441)

# %%
# print column names
print(df.columns.values)
# Out:
# ['Flex-Left-1-Frame-1' 'Flex-Left-1-Frame-2' 'Flex-Left-1-Frame-3'
#  'Flex-Left-1-Frame-4' 'Flex-Left-1-Frame-5' 'Flex-Left-1-Frame-6'
#  'Flex-Left-1-Frame-7' 'Flex-Left-1-Frame-8' 'Flex-Left-1-Frame-9'
#  'Flex-Left-1-Frame-10' 'Flex-Left-1-Frame-11' 'Flex-Left-1-Frame-12'
#  'Flex-Left-1-Frame-13' 'Flex-Left-1-Frame-14' 'Flex-Left-1-Frame-15'
#  'Flex-Left-1-Frame-16' 'Flex-Left-1-Frame-17' 'Flex-Left-1-Frame-18'
#  'Flex-Left-1-Frame-19' 'Flex-Left-1-Frame-20' 'Flex-Left-2-Frame-1'
#  'Flex-Left-2-Frame-2' 'Flex-Left-2-Frame-3' 'Flex-Left-2-Frame-4'
#  'Flex-Left-2-Frame-5' 'Flex-Left-2-Frame-6' 'Flex-Left-2-Frame-7'
#  'Flex-Left-2-Frame-8' 'Flex-Left-2-Frame-9' 'Flex-Left-2-Frame-10'
#  'Flex-Left-2-Frame-11' 'Flex-Left-2-Frame-12' 'Flex-Left-2-Frame-13'
#  'Flex-Left-2-Frame-14' 'Flex-Left-2-Frame-15' 'Flex-Left-2-Frame-16'
#  'Flex-Left-2-Frame-17' 'Flex-Left-2-Frame-18' 'Flex-Left-2-Frame-19'
#  'Flex-Left-2-Frame-20' 'Flex-Left-3-Frame-1' 'Flex-Left-3-Frame-2'
# ...

# %%
df.head()
# Out:
#    Flex-Left-1-Frame-1  Flex-Left-1-Frame-2  Flex-Left-1-Frame-3  \
# 0                  168                  163                  160
# 1                  178                  176                  179
# 2                  173                  172                  172
# 3                  179                  179                  176
# 4                  172                  172                  173
#
#    Flex-Left-1-Frame-4  Flex-Left-1-Frame-5  Flex-Left-1-Frame-6  \
# 0                  146                  169                  172
# 1                  175                  179                  176
# 2                  178                  175                  184
# 3                  176                  175                  170
# 4                  172                  169                  169
#
#    Flex-Left-1-Frame-7  Flex-Left-1-Frame-8  Flex-Left-1-Frame-9  \
# 0                  185                  198                  210
# ...

# %%
df.tail()
# Out:
#     Flex-Left-1-Frame-1  Flex-Left-1-Frame-2  Flex-Left-1-Frame-3  \
# 75                  158                  158                  158
# 76                  166                  167                  167
# 77                  169                  174                  170
# 78                  164                  166                  166
# 79                  164                  164                  164
#
#     Flex-Left-1-Frame-4  Flex-Left-1-Frame-5  Flex-Left-1-Frame-6  \
# 75                  157                  164                  164
# 76                  167                  169                  161
# 77                  169                  171                  166
# 78                  166                  170                  173
# 79                  169                  173                  173
#
#     Flex-Left-1-Frame-7  Flex-Left-1-Frame-8  Flex-Left-1-Frame-9  \
# 75                  161                  171                  190
# ...

# %%
# print position columns (x, y, z)
df[['Position-X-Left-Frame-1','Position-Y-Left-Frame-1','Position-Z-Left-Frame-1', 'Position-X-Right-Frame-1','Position-Y-Right-Frame-1','Position-Z-Right-Frame-1']].head(10)
# Out:
#    Position-X-Left-Frame-1  Position-Y-Left-Frame-1  Position-Z-Left-Frame-1  \
# 0                     0.31                    -0.42                     0.27
# 1                    -0.01                     0.43                     0.07
# 2                    -0.06                    -0.08                    -0.00
# 3                    -0.05                     0.10                     0.04
# 4                    -0.05                     0.11                    -0.04
# 5                     0.09                    -0.16                     0.04
# 6                     0.00                     0.04                    -0.03
# 7                    -0.01                     0.10                    -0.04
# 8                     0.01                     0.03                    -0.02
# 9                     0.04                     0.01                     0.03
#
#    Position-X-Right-Frame-1  Position-Y-Right-Frame-1  \
# 0                     -0.18                     -0.37
# ...

# %%
df[['Position-X-Left-Frame-5','Position-Y-Left-Frame-5','Position-Z-Left-Frame-5', 'Position-X-Right-Frame-5','Position-Y-Right-Frame-5','Position-Z-Right-Frame-5']].head(10)
# Out:
#      Position-X-Left-Frame-5  Position-Y-Left-Frame-5  \
# 24                      0.07                 -3574.03
# 168                     1.32                 -3574.67
# 173                     1.19                 -3574.76
# 168                     1.24                 -3574.81
# 170                     1.26                 -3574.61
# 176                     1.07                 -3574.86
# 181                     0.96                 -3575.01
# 174                     1.19                 -3574.71
# 178                     1.18                 -3574.71
# 171                     0.91                 -3574.75
#
#      Position-Z-Left-Frame-5  Position-X-Right-Frame-5  \
# 24                     -0.01                      0.02
# 168                    -0.54                      1.25
# 173                    -0.41                      0.79
# 168                    -0.39                      1.12
# 170                    -0.55                      1.22
# ...

# %%
df[['Position-X-Left-Frame-10','Position-Y-Left-Frame-10','Position-Z-Left-Frame-10', 'Position-X-Right-Frame-10','Position-Y-Right-Frame-10','Position-Z-Right-Frame-10']].head(10)
# Out:
#      Position-X-Left-Frame-10  Position-Y-Left-Frame-10  \
# 24                       0.12                  -3574.02
# 168                     -0.56                  -3574.73
# 173                     -0.69                  -3574.72
# 168                     -0.59                  -3574.83
# 170                     -0.50                  -3574.75
# 176                     -0.46                  -3574.75
# 181                     -0.57                  -3574.68
# 174                      0.28                  -3574.91
# 178                      0.36                  -3575.07
# 171                     -0.74                  -3574.71
#
#      Position-Z-Left-Frame-10  Position-X-Right-Frame-10  \
# 24                       0.00                       0.16
# 168                      0.26                      -0.60
# 173                      0.26                      -0.71
# 168                      0.21                      -0.61
# 170                      0.28                      -0.58
# ...

# %%
df[['Position-X-Left-Frame-15','Position-Y-Left-Frame-15','Position-Z-Left-Frame-15', 'Position-X-Right-Frame-15','Position-Y-Right-Frame-15','Position-Z-Right-Frame-15']].head(10)
# Out:
#      Position-X-Left-Frame-15  Position-Y-Left-Frame-15  \
# 24                       0.25                  -3574.06
# 168                     -0.12                  -3575.28
# 173                      0.22                  -3575.61
# 168                     -0.35                  -3575.02
# 170                     -0.60                  -3574.68
# 176                      0.29                  -3575.32
# 181                      0.21                  -3575.38
# 174                     -0.61                  -3574.20
# 178                     -0.26                  -3574.97
# 171                      0.00                  -3575.46
#
#      Position-Z-Left-Frame-15  Position-X-Right-Frame-15  \
# 24                      -0.10                       0.38
# 168                     -0.57                       0.04
# 173                     -0.40                       0.12
# 168                     -0.23                      -0.17
# 170                      0.15                      -0.40
# ...

# %%
df[['Position-X-Left-Frame-1','Position-Y-Left-Frame-1','Position-Z-Left-Frame-1', 'Position-X-Right-Frame-1','Position-Y-Right-Frame-1','Position-Z-Right-Frame-1']].tail(10)
# Out:
#      Position-X-Left-Frame-1  Position-Y-Left-Frame-1  \
# 179                     1.20                 -3574.71
# 171                     1.18                 -3574.74
# 171                     1.18                 -3574.69
# 199                     0.89                 -3574.81
# 158                    -0.05                 -4279.03
# 171                     1.12                 -4279.89
# 163                     1.12                 -4279.90
# 173                     1.12                 -4279.91
# 171                     1.13                 -4279.92
# 168                     1.13                 -4279.91
#
#      Position-Z-Left-Frame-1  Position-X-Right-Frame-1  \
# 179                     0.29                      1.23
# 171                     0.28                      1.28
# 171                     0.26                      1.32
# 199                    -0.48                      0.19
# 158                     0.15                      0.04
# ...

# %%
df[['Position-X-Left-Frame-5','Position-Y-Left-Frame-5','Position-Z-Left-Frame-5', 'Position-X-Right-Frame-5','Position-Y-Right-Frame-5','Position-Z-Right-Frame-5']].tail(10)
# Out:
#      Position-X-Left-Frame-5  Position-Y-Left-Frame-5  \
# 199                    -0.61                 -3574.42
# 158                    -0.03                 -4279.06
# 171                     1.15                 -4279.77
# 163                     1.11                 -4279.88
# 173                     1.15                 -4279.91
# 171                     1.17                 -4279.78
# 168                     1.17                 -4279.81
# 250                     0.15                 -3971.91
# 164                     1.19                 -3972.98
# 172                     1.18                 -3972.72
#
#      Position-Z-Left-Frame-5  Position-X-Right-Frame-5  \
# 199                     0.12                     -0.66
# 158                     0.15                     -0.01
# 171                    -0.85                      1.09
# 163                    -0.53                      1.26
# 173                    -0.75                      1.17
# ...

# %%
df[['Position-X-Left-Frame-10','Position-Y-Left-Frame-10','Position-Z-Left-Frame-10', 'Position-X-Right-Frame-10','Position-Y-Right-Frame-10','Position-Z-Right-Frame-10']].tail(10)
# Out:
#      Position-X-Left-Frame-10  Position-Y-Left-Frame-10  \
# 199                     -0.24                  -3574.94
# 158                     -0.23                  -4279.14
# 171                     -0.63                  -4279.99
# 163                     -0.26                  -4280.27
# 173                     -0.55                  -4279.96
# 171                     -0.31                  -4280.01
# 168                     -0.61                  -4279.92
# 250                      0.82                  -3972.39
# 164                     -0.73                  -3972.73
# 172                     -0.72                  -3972.77
#
#      Position-Z-Left-Frame-10  Position-X-Right-Frame-10  \
# 199                     -1.01                      -0.02
# 158                      0.10                      -0.07
# 171                     -0.00                      -0.65
# 163                     -0.04                      -0.49
# 173                      0.11                      -0.63
# ...

# %%
# count lines with STUDENT in the SIGN column
df[df['SIGN'] == 'THIS'].count()
# Out:
# Flex-Left-1-Frame-1             100
# Flex-Left-1-Frame-2             100
# Flex-Left-1-Frame-3             100
# Flex-Left-1-Frame-4             100
# Flex-Left-1-Frame-5             100
#                                ...
# Orientation-Z-Right-Frame-19    100
# Orientation-X-Right-Frame-20    100
# Orientation-Y-Right-Frame-20    100
# Orientation-Z-Right-Frame-20    100
# SIGN                            100
# Length: 441, dtype: int64

# %%
# count nan values
df.isnull().sum()
# Out:
# Flex-Left-1-Frame-1             0
# Flex-Left-1-Frame-2             0
# Flex-Left-1-Frame-3             0
# Flex-Left-1-Frame-4             0
# Flex-Left-1-Frame-5             0
#                                ..
# Orientation-Z-Right-Frame-19    0
# Orientation-X-Right-Frame-20    0
# Orientation-Y-Right-Frame-20    0
# Orientation-Z-Right-Frame-20    0
# SIGN                            0
# Length: 441, dtype: int64
